# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

from matplotlib import colors

# %%
def plot_from_npy(npy_file, save_path=None):
    data = np.load(npy_file)
    fig, ax = plt.subplots(1,1, figsize=(5, 4))

    cmap = mpl.cm.get_cmap("jet").copy()
    cmap.set_under(color='white')
    
    imag = ax.imshow(data.sum(axis=0)[:,:,2].transpose() / data.shape[0], extent=[-1, 1, -1, 1], aspect='equal', norm=colors.SymLogNorm(linthresh=0.0001, linscale=0.1, vmin=1e-2, vmax=1e1), cmap=cmap, origin='lower')
    cbar = plt.colorbar(imag, ax=ax, shrink=0.9)

    ax.set_xlabel(r'$\eta^\prime$') 
    ax.set_ylabel(r'$\phi^\prime$')

    cbar.set_label(r'$ p_{\mathrm{T}}$ [GeV]', rotation=90, labelpad=5)

    if save_path:
        plt.savefig(save_path, dpi=300, facecolor='White', bbox_inches='tight')

    plt.show()

    return data.sum(axis=0)[:,:,0].transpose() / data.shape[0]

def plot_jet_image(data, save_path=None):
    fig, ax = plt.subplots(1,1, figsize=(5, 4))

    cmap = mpl.cm.get_cmap("jet").copy()
    cmap.set_under(color='white')

    imag = ax.imshow(data, extent=[-1.0, 1.0, -1.0, 1.0], norm=colors.SymLogNorm(linthresh=0.0001, linscale=0.1, vmin=1e-3, vmax=1e3), cmap=cmap, origin='lower')
    cbar = plt.colorbar(imag, ax=ax, shrink=0.9)

    ax.set_xlabel(r'$\eta^\prime$') 
    ax.set_ylabel(r'$\phi^\prime$')

    cbar.set_label(r'$ p_{\mathrm{T}}$ [GeV]', rotation=90, labelpad=5)

    if save_path:
        plt.savefig(save_path, dpi=300, facecolor='White', bbox_inches='tight')

    plt.show()

    return data

# %%
def plot_image_on_axis(data, ax):
    cmap = mpl.cm.get_cmap("jet").copy()
    cmap.set_under(color='white')

    imag = ax.imshow(data, extent=[-5, 5, -np.pi, np.pi], aspect=5/np.pi, norm=colors.SymLogNorm(linthresh=0.0001, linscale=0.1, vmin=1e-1, vmax=1e3), cmap=cmap, origin='lower')
    cbar = plt.colorbar(imag, ax=ax, shrink=0.9)
    
    cbar.set_label(r'$ p_{\mathrm{T}}$ [GeV]', rotation=90, labelpad=5)

    ax.set_xlabel(r'$\eta$') 
    ax.set_ylabel(r'$\phi^\prime$')

# %% [markdown]
# # Event image

# %%
data_ppZp = plot_from_npy('./data/pre-processing/40x40/ppZp-03-data.npy')
data_ppWW = plot_from_npy('./data/pre-processing/40x40/ppWW-03-data.npy')
data_ppZZ = plot_from_npy('./data/pre-processing/40x40/ppZZ-03-data.npy')

# %% [markdown]
# ## $pp \to Z'$

# %%
data = np.load('./data/pre-processing/40x40/ppZp-03-data.npy')
event = 2
fig, ax = plt.subplots(1, 1, figsize=(5, 4))

plot_image_on_axis(data[event, :, :, 0].transpose(), ax)
    
# 調整子圖間的水平間距
plt.subplots_adjust(wspace=0.25)
plt.savefig('../figures/event_image_ppZp-tower.pdf', dpi=300, facecolor='White', bbox_inches='tight')
plt.show()


fig, ax = plt.subplots(1, 1, figsize=(5, 4))

plot_image_on_axis(data[event, :, :, 1].transpose(), ax)
    
# 調整子圖間的水平間距
plt.subplots_adjust(wspace=0.25)
plt.savefig('../figures/event_image_ppZp-track.pdf', dpi=300, facecolor='White', bbox_inches='tight')
plt.show()


fig, ax = plt.subplots(1, 1, figsize=(5, 4))

plot_image_on_axis(data[event, :, :, 2].transpose(), ax)
    
# 調整子圖間的水平間距
plt.subplots_adjust(wspace=0.25)
plt.savefig('../figures/event_image_ppZp-lepton.pdf', dpi=300, facecolor='White', bbox_inches='tight')
plt.show()

# %% [markdown]
# ## $pp \to W^+ W^-$

# %%
data = np.load('./data/pre-processing/40x40/ppWW-03-data.npy')
event = 7
fig, ax = plt.subplots(1, 1, figsize=(5, 4))

plot_image_on_axis(data[event, :, :, 0].transpose(), ax)
    
# 調整子圖間的水平間距
plt.subplots_adjust(wspace=0.25)
plt.savefig('../figures/event_image_ppWW-tower.pdf', dpi=300, facecolor='White', bbox_inches='tight')
plt.show()


fig, ax = plt.subplots(1, 1, figsize=(5, 4))

plot_image_on_axis(data[event, :, :, 1].transpose(), ax)
    
# 調整子圖間的水平間距
plt.subplots_adjust(wspace=0.25)
plt.savefig('../figures/event_image_ppWW-track.pdf', dpi=300, facecolor='White', bbox_inches='tight')
plt.show()


fig, ax = plt.subplots(1, 1, figsize=(5, 4))

plot_image_on_axis(data[event, :, :, 2].transpose(), ax)
    
# 調整子圖間的水平間距
plt.subplots_adjust(wspace=0.25)
plt.savefig('../figures/event_image_ppWW-lepton.pdf', dpi=300, facecolor='White', bbox_inches='tight')
plt.show()

# %%
data = np.load('./data/pre-processing/40x40/ppZZ-03-data.npy')
event = 7
fig, ax = plt.subplots(1, 1, figsize=(5, 4))

plot_image_on_axis(data[event, :, :, 0].transpose(), ax)
    
# 調整子圖間的水平間距
plt.subplots_adjust(wspace=0.25)
plt.savefig('../figures/event_image_ppZZ-tower.pdf', dpi=300, facecolor='White', bbox_inches='tight')
plt.show()


fig, ax = plt.subplots(1, 1, figsize=(5, 4))

plot_image_on_axis(data[event, :, :, 1].transpose(), ax)
    
# 調整子圖間的水平間距
plt.subplots_adjust(wspace=0.25)
plt.savefig('../figures/event_image_ppZZ-track.pdf', dpi=300, facecolor='White', bbox_inches='tight')
plt.show()


fig, ax = plt.subplots(1, 1, figsize=(5, 4))

plot_image_on_axis(data[event, :, :, 2].transpose(), ax)
    
# 調整子圖間的水平間距
plt.subplots_adjust(wspace=0.25)
plt.savefig('../figures/event_image_ppZZ-lepton.pdf', dpi=300, facecolor='White', bbox_inches='tight')
plt.show()
