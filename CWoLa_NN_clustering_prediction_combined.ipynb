# %%
import os
import ternary
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt


from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

from sklearn.cluster import KMeans, SpectralClustering

os.environ['CUDA_VISIBLE_DEVICES'] = '1'
# solve the problem of "libdevice not found at ./libdevice.10.bc"
os.environ['XLA_FLAGS'] = '--xla_gpu_cuda_data_dir=/home/r10222035/.conda/envs/tf2'
# Out:
# 2025-01-03 13:00:08.416912: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-01-03 13:00:08.556903: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %% [markdown]
# # Datasets

# %%
# prepare fake data: three 5D Gaussian distributions
muA = [0, 0, 0, 0, 0]
covA = np.eye(5)
muB = [1, 1, 1, 1, 1]
covB = np.eye(5)
muC = [-1, -1, -1, -1, -1]
covC = np.eye(5)

# dominated case 1
case_name = 'dominated_1'
f1A, f1B, f1C = 0.7, 0.2, 0.1
f2A, f2B, f2C = 0.1, 0.7, 0.2
f3A, f3B, f3C = 0.2, 0.1, 0.7

# # dominated case 2
# f1A, f1B, f1C = 0.80, 0.10, 0.10
# f2A, f2B, f2C = 0.70, 0.25, 0.05
# f3A, f3B, f3C = 0.60, 0.20, 0.20

# # ambiguous case
# case_name = 'ambiguous'
# f1A, f1B, f1C = 0.80, 0.10, 0.10
# f2A, f2B, f2C = 0.70, 0.20, 0.10
# f3A, f3B, f3C = 0.60, 0.25, 0.15

# set random seed
np.random.seed(24)

def generate_data(n_samples=10000):
    
    fractions = np.array([[f1A, f1B, f1C], [f2A, f2B, f2C], [f3A, f3B, f3C]])

    # normalize fractions
    fractions = fractions / fractions.sum(axis=1)[:, None]

    n_A_1, n_B_1, n_C_1 = (fractions[0] * n_samples).astype(int)
    n_A_2, n_B_2, n_C_2 = (fractions[1] * n_samples).astype(int)
    n_A_3, n_B_3, n_C_3 = (fractions[2] * n_samples).astype(int)
    
    M1 = np.concatenate([np.random.multivariate_normal(muA, covA, size=n_A_1),
                         np.random.multivariate_normal(muB, covB, size=n_B_1),
                         np.random.multivariate_normal(muC, covC, size=n_C_1)])
    
    M2 = np.concatenate([np.random.multivariate_normal(muA, covA, size=n_A_2),
                            np.random.multivariate_normal(muB, covB, size=n_B_2),
                            np.random.multivariate_normal(muC, covC, size=n_C_2)])
    
    M3 = np.concatenate([np.random.multivariate_normal(muA, covA, size=n_A_3),
                            np.random.multivariate_normal(muB, covB, size=n_B_3),
                            np.random.multivariate_normal(muC, covC, size=n_C_3)])
    
    X = np.concatenate([M1, M2, M3])
    # one-hot encoding
    y = np.concatenate([np.tile([1, 0, 0], (M1.shape[0], 1)),
                        np.tile([0, 1, 0], (M2.shape[0], 1)),
                        np.tile([0, 0, 1], (M3.shape[0], 1))])
    
    y_true = np.concatenate([np.tile([1, 0, 0], (n_A_1, 1)),
                             np.tile([0, 1, 0], (n_B_1, 1)),
                             np.tile([0, 0, 1], (n_C_1, 1)),
                             np.tile([1, 0, 0], (n_A_2, 1)),
                             np.tile([0, 1, 0], (n_B_2, 1)),
                             np.tile([0, 0, 1], (n_C_2, 1)),
                             np.tile([1, 0, 0], (n_A_3, 1)),
                             np.tile([0, 1, 0], (n_B_3, 1)),
                             np.tile([0, 0, 1], (n_C_3, 1))])
    
    return X, y, y_true

# %%
n_test = 1000
X_test = np.concatenate([np.random.multivariate_normal(muA, covA, size=n_test), 
                         np.random.multivariate_normal(muB, covB, size=n_test),
                         np.random.multivariate_normal(muC, covC, size=n_test)])
y_test = np.concatenate([np.tile([1, 0, 0], (n_test, 1)),
                         np.tile([0, 1, 0], (n_test, 1)),
                         np.tile([0, 0, 1], (n_test, 1))])

# %%
def plot_event_distribution(X, y, y_true, save_path=None):
    if X.shape[0] > 400:
        idx = np.random.choice(X.shape[0], 400, replace=False)
        X = X[idx]
        y = y[idx]
        y_true = y_true[idx]

    y = np.argmax(y, axis=1)
    y_true = np.argmax(y_true, axis=1)

    # plot the event distribution
    fig, ax = plt.subplots(1, 3, figsize=(15, 4))

    ax[0].scatter(X[(y==0) & (y_true==0)][:, 0], X[(y==0) & (y_true==0)][:, 1], c='b', marker='x', alpha=0.3, label='$M_1$')
    ax[0].scatter(X[(y==1) & (y_true==0)][:, 0], X[(y==1) & (y_true==0)][:, 1], c='r', marker='+', alpha=0.3, label='$M_2$')
    ax[0].scatter(X[(y==2) & (y_true==0)][:, 0], X[(y==2) & (y_true==0)][:, 1], c='g', marker='o', alpha=0.3, label='$M_3$')
    ax[0].legend(frameon=False)
    ax[0].set_title('Class $A$')
    ax[0].set_xlabel('Feature 1')
    ax[0].set_ylabel('Feature 2')

    ax[0].set_xlim(-4, 6)
    ax[0].set_ylim(-4, 6)


    ax[1].scatter(X[(y==0) & (y_true==1)][:, 0], X[(y==0) & (y_true==1)][:, 1], c='b', marker='x', alpha=0.3, label='$M_1$')
    ax[1].scatter(X[(y==1) & (y_true==1)][:, 0], X[(y==1) & (y_true==1)][:, 1], c='r', marker='+', alpha=0.3, label='$M_2$')
    ax[1].scatter(X[(y==2) & (y_true==1)][:, 0], X[(y==2) & (y_true==1)][:, 1], c='g', marker='o', alpha=0.3, label='$M_3$')
    ax[1].legend(frameon=False)
    ax[1].set_title('Class $B$')
    ax[1].set_xlabel('Feature 1')
    ax[1].set_ylabel('Feature 2')

    ax[1].set_xlim(-4, 6)
    ax[1].set_ylim(-4, 6)

    ax[2].scatter(X[(y==0) & (y_true==2)][:, 0], X[(y==0) & (y_true==2)][:, 1], c='b', marker='x', alpha=0.3, label='$M_1$')
    ax[2].scatter(X[(y==1) & (y_true==2)][:, 0], X[(y==1) & (y_true==2)][:, 1], c='r', marker='+', alpha=0.3, label='$M_2$')
    ax[2].scatter(X[(y==2) & (y_true==2)][:, 0], X[(y==2) & (y_true==2)][:, 1], c='g', marker='o', alpha=0.3, label='$M_3$')
    ax[2].legend(frameon=False)
    ax[2].set_title('Class $C$')
    ax[2].set_xlabel('Feature 1')
    ax[2].set_ylabel('Feature 2')

    ax[2].set_xlim(-4, 6)
    ax[2].set_ylim(-4, 6)

    if save_path:
        plt.savefig(save_path, dpi=300, facecolor='White', bbox_inches='tight')
    plt.show()

# %%
X_train, y_train, y_true = generate_data()
X_val, y_val, y_true_val = generate_data(n_samples=1000)

save_path = f'./figures/multi-class_training_data-{case_name}.pdf'
save_path = None
plot_event_distribution(X_train, y_train, y_true, save_path)

# %% [markdown]
# # Training neural network

# %%
def plot_event_score_distribution(y, y_score, y_predict_label=None, dataset='train', save_path=None):
    
    if len(y.shape) == 2:
        y = np.argmax(y, axis=1)

    if y_predict_label is None:
        y_predict_label = y_score.argmax(axis=1)

    # 定義映射規則 (以陣列形式表示)
    mappings = np.array([
        [0, 1, 2],  # 原始
        [0, 2, 1],  # 0->0, 1->2, 2->1
        [2, 1, 0],  # 0->2, 1->1, 2->0
        [1, 0, 2],  # 0->1, 1->0, 2->2
        [2, 0, 1],  # 0->2, 1->0, 2->1
        [1, 2, 0],  # 0->1, 1->2, 2->0
    ])

    # 使用 NumPy 高效映射
    all_arrays = mappings[:, y_predict_label]

    ACC = 0
    # 輸出所有結果
    for i, arr in enumerate(all_arrays, 1):
        ACC_tem = (y == arr).mean()
        if ACC_tem > ACC:
            ACC = ACC_tem
            y_predict_label = arr

    ACC = (y == y_predict_label).mean()
    
    ACCs = []
    for i in range(3):
        ACCs.append((y[y == i] == y_predict_label[y == i]).mean())

    print(f'ACC: {ACC:.3f}, ACCs: {ACCs}') 

    if y.shape[0] > 400:
        idx = np.random.choice(y.shape[0], 400, replace=False)
        y = y[idx]
        y_score = y_score[idx]

    # 畫 event score 的分布
    if dataset == 'train':
        labels = ['$M_1$', '$M_2$', '$M_3$']
        title = 'Training set'
    elif dataset == 'test':
        labels = ['$A$', '$B$', '$C$']
        title = 'Testing set'

    # 設定繪圖範圍
    figure, tax = ternary.figure(scale=1)
    tax.set_title(f'{title}: ACC = {ACC:.3f}', fontsize=15)

    # 設定軸標籤
    tax.bottom_axis_label('Event score 1', fontsize=12, offset=0.2)
    tax.right_axis_label('Event score 2', fontsize=12)
    tax.left_axis_label('Event score 3', fontsize=12)

    # 生成主導區域的分界線點
    # 這些線表示當某個組分等於其他組分時的情況
    line_points_A = [(1/3, 1/3, 1/3), (0.5, 0.5, 0)]  # A = B > C
    line_points_B = [(1/3, 1/3, 1/3), (0, 0.5, 0.5)]  # B = C > A
    line_points_C = [(1/3, 1/3, 1/3), (0.5, 0, 0.5)]  # A = C > B

    # 繪製分界線
    tax.plot([line_points_A[0], line_points_A[1]], linewidth=2, color='grey', linestyle='--')
    tax.plot([line_points_B[0], line_points_B[1]], linewidth=2, color='grey', linestyle='--')
    tax.plot([line_points_C[0], line_points_C[1]], linewidth=2, color='grey', linestyle='--')
    
    # 添加區域標籤
    tax.annotate('1', (0.6, 0.12, 0.28), fontsize=50, alpha= 0.5, color='grey')
    tax.annotate('2', (0.2, 0.52, 0.28), fontsize=50, alpha= 0.5, color='grey')
    tax.annotate('3', (0.2, 0.12, 0.68), fontsize=50, alpha= 0.5, color='grey')

    # 繪製數據點
    tax.scatter(y_score[y == 0], marker='x', color='b', alpha=0.3, label=f'{labels[0]}: ACC = {ACCs[0]:.3f}')
    tax.scatter(y_score[y == 1], marker='+', color='r', alpha=0.3, label=f'{labels[1]}: ACC = {ACCs[1]:.3f}')
    tax.scatter(y_score[y == 2], marker='o', color='g', alpha=0.3, label=f'{labels[2]}: ACC = {ACCs[2]:.3f}')

    # 設置樣式
    tax.boundary(linewidth=2.0)
    tax.gridlines(multiple=0.1, color="gray")

    # 添加刻度
    tax.ticks(axis='lbr', multiple=0.2, linewidth=1, offset=0.03, tick_formats="%.1f")

    # 移除外部邊框
    tax.get_axes().spines['top'].set_visible(False)
    tax.get_axes().spines['right'].set_visible(False)
    tax.get_axes().spines['bottom'].set_visible(False)
    tax.get_axes().spines['left'].set_visible(False)

    # 添加圖例
    tax.legend(frameon=False)

    # 確保圖形緊湊
    tax.clear_matplotlib_ticks()
    tax.get_axes().axis('equal')

    if save_path:
        plt.savefig(save_path, dpi=300, facecolor='White', bbox_inches='tight')
        
    # 顯示圖形
    plt.tight_layout()
    plt.show()

# %%
def get_accuracy(y_true, y_pred, permute=True):

    if permute:
        # 定義映射規則 (以陣列形式表示)
        mappings = np.array([
            [0, 1, 2],  # 原始
            [0, 2, 1],  # 0->0, 1->2, 2->1
            [2, 1, 0],  # 0->2, 1->1, 2->0
            [1, 0, 2],  # 0->1, 1->0, 2->2
            [2, 0, 1],  # 0->2, 1->0, 2->1
            [1, 2, 0],  # 0->1, 1->2, 2->0
        ])

        all_arrays = mappings[:, y_pred]

        # evaluate ACC for all mappings
        ACC = 0
        for i, arr in enumerate(all_arrays):
            ACC_tem = (y_true == arr).mean()
            if ACC_tem > ACC:
                ACC = ACC_tem
                y_pred = arr

    ACC = (y_true == y_pred).mean()
    
    ACCs = []
    for i in range(3):
        ACCs.append((y_true[y_true == i] == y_pred[y_true == i]).mean())

    return ACC, ACCs, y_pred
    
def plot_predict_results(y, y_score, y_predict_label, title='Clustering', save_path=None):
    
    if len(y.shape) == 2:
        y = np.argmax(y, axis=1)

    permute = False if title == 'Max argument' else True
    ACC, ACCs, y_predict_label = get_accuracy(y, y_predict_label, permute)

    if y.shape[0] > 400:
        # set random seed
        np.random.seed(356)
        idx = np.random.choice(y.shape[0], 400, replace=False)
        y = y[idx]
        y_score = y_score[idx]
        y_predict_label = y_predict_label[idx]

    # plot the clustering result
    fig, ax = plt.subplots(1, 1, figsize=(6, 5))

    xlim = y_score[:, 0].min(), y_score[:, 0].max()
    ylim = y_score[:, 1].min(), y_score[:, 1].max()

    ax.scatter(y_score[(y == 0) & (y_predict_label == 0)][:, 0], y_score[(y == 0) & (y_predict_label == 0)][:, 1], c='b', marker='$A$', label=f' ')
    ax.scatter(y_score[(y == 0) & (y_predict_label == 1)][:, 0], y_score[(y == 0) & (y_predict_label == 1)][:, 1], c='r', marker='$A$', label=f' ')
    ax.scatter(y_score[(y == 0) & (y_predict_label == 2)][:, 0], y_score[(y == 0) & (y_predict_label == 2)][:, 1], c='g', marker='$A$', label=f' ')
    ax.scatter(y_score[(y == 1) & (y_predict_label == 0)][:, 0], y_score[(y == 1) & (y_predict_label == 0)][:, 1], c='b', marker='$B$', label=f' ')
    ax.scatter(y_score[(y == 1) & (y_predict_label == 1)][:, 0], y_score[(y == 1) & (y_predict_label == 1)][:, 1], c='r', marker='$B$', label=f' ')
    ax.scatter(y_score[(y == 1) & (y_predict_label == 2)][:, 0], y_score[(y == 1) & (y_predict_label == 2)][:, 1], c='g', marker='$B$', label=f' ')
    ax.scatter(y_score[(y == 2) & (y_predict_label == 0)][:, 0], y_score[(y == 2) & (y_predict_label == 0)][:, 1], c='b', marker='$C$', label=f' ')
    ax.scatter(y_score[(y == 2) & (y_predict_label == 1)][:, 0], y_score[(y == 2) & (y_predict_label == 1)][:, 1], c='r', marker='$C$', label=f' ')
    ax.scatter(y_score[(y == 2) & (y_predict_label == 2)][:, 0], y_score[(y == 2) & (y_predict_label == 2)][:, 1], c='g', marker='$C$', label=f' ')

    # plot boundary lines
    ax.plot([1/3, 0.5], [1/3, 0.5], linewidth=2, color='grey', linestyle='--')
    ax.plot([1/3, 0.0], [1/3, 0.5], linewidth=2, color='grey', linestyle='--')
    ax.plot([1/3, 0.5], [1/3, 0.0], linewidth=2, color='grey', linestyle='--')
    ax.plot([0, 1], [1, 0], linewidth=1, color='black', linestyle='-')

    ax.set_title(f'{title}: ACC = {ACC:.3f}')
    ax.set_xlabel('Event score 1')
    ax.set_ylabel('Event score 2')
    ax.set_xlim(xlim)
    ax.set_ylim(ylim)

    handles, labels = ax.get_legend_handles_labels()
    n = 3
    handles = [(handles[i * n], handles[i * n + 1], handles[i * n + 2]) for i in range(3)]
    labels = [f'ACC = {ACCs[0]:.3f}', f'ACC = {ACCs[1]:.3f}', f'ACC = {ACCs[2]:.3f}']
    handler_map = {tuple: plt.matplotlib.legend_handler.HandlerTuple(ndivide=None)}
    ax.legend(handles, labels, handler_map=handler_map, frameon=False)

    if save_path:
        plt.savefig(save_path, dpi=300, facecolor='White', bbox_inches='tight')

    plt.show()

# %%
# build multi-class classification model
def build_model(input_dim, n_class=3):
    model = Sequential()
    model.add(Dense(8, input_dim=input_dim, activation='relu'))
    model.add(Dense(8, activation='relu'))
    model.add(Dense(n_class, activation='softmax'))
    model.compile(optimizer=tf.keras.optimizers.Adam(1e-2),
                  loss=tf.keras.losses.CategoricalCrossentropy(from_logits=False),
                  metrics=['accuracy'])
    return model

# %%
def training_nn(X_train, y_train, X_val, y_val, y_true, X_test, y_test):

    # 檢查每個類別的數量
    n_A_1 = np.sum(y_true[y_train.argmax(axis=1) == 0].argmax(axis=1) == 0)
    n_B_1 = np.sum(y_true[y_train.argmax(axis=1) == 0].argmax(axis=1) == 1)
    n_C_1 = np.sum(y_true[y_train.argmax(axis=1) == 0].argmax(axis=1) == 2)
    n_A_2 = np.sum(y_true[y_train.argmax(axis=1) == 1].argmax(axis=1) == 0)
    n_B_2 = np.sum(y_true[y_train.argmax(axis=1) == 1].argmax(axis=1) == 1)
    n_C_2 = np.sum(y_true[y_train.argmax(axis=1) == 1].argmax(axis=1) == 2)
    n_A_3 = np.sum(y_true[y_train.argmax(axis=1) == 2].argmax(axis=1) == 0)
    n_B_3 = np.sum(y_true[y_train.argmax(axis=1) == 2].argmax(axis=1) == 1)
    n_C_3 = np.sum(y_true[y_train.argmax(axis=1) == 2].argmax(axis=1) == 2)
    print(f'M1: A: {n_A_1}, B: {n_B_1}, C: {n_C_1}')
    print(f'M2: A: {n_A_2}, B: {n_B_2}, C: {n_C_2}')
    print(f'M3: A: {n_A_3}, B: {n_B_3}, C: {n_C_3}')

    # print fraction
    N = np.array([[n_A_1, n_B_1, n_C_1], [n_A_2, n_B_2, n_C_2], [n_A_3, n_B_3, n_C_3]])
    fractions = N / N.sum(axis=1)[:, None]
    print(f'Fractions: {fractions}')


    # 建立模型並訓練
    model = build_model(X_train.shape[1])
    early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=0, verbose=1, patience=10)
    history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=200, batch_size=1024, verbose=1, callbacks=[early_stopping,])

    # plot the training loss, accuracy
    fig, ax = plt.subplots(1, 2, figsize=(10, 4))

    x = range(1, len(history.history['loss']) + 1)

    ax[0].plot(x, history.history['loss'], label='Training')
    ax[0].plot(x, history.history['val_loss'], label='Validation')


    ax[0].legend(frameon=False)
    ax[0].set_title(f'model loss')
    ax[0].set_xlabel('Epoch')
    ax[0].set_ylabel('Loss')

    ax[1].plot(x, history.history['accuracy'], label='Training')
    ax[1].plot(x, history.history['val_accuracy'], label='Validation')


    ax[1].legend(frameon=False)
    ax[1].set_title(f'model accuracy')
    ax[1].set_xlabel('Epoch')
    ax[1].set_ylabel('Accuracy')
    plt.show()


    # plot the event score distribution for training set
    y_predict = model.predict(X_train, batch_size=1024)
    plot_event_score_distribution(y_train, y_predict, dataset='train')

    results = model.evaluate(x=X_train, y=y_train, batch_size=1024)
    print(f'Training Loss = {results[0]:.3}, Training Accuracy = {results[1]:.3}')

    # plot the event score distribution for testing set
    y_test_predict = model.predict(X_test, batch_size=1024)
    plot_event_score_distribution(y_test, y_test_predict, dataset='test')

    results = model.evaluate(x=X_test, y=y_test, batch_size=1024)
    print(f'Testing Loss = {results[0]:.3}, Testing Accuracy = {results[1]:.3}')

    return model

# %%
model = training_nn(X_train, y_train, X_val, y_val, y_true, X_test, y_test)
y_predict = model.predict(X_train, batch_size=1024)
y_test_predict = model.predict(X_test, batch_size=1024)
# Out:
# M1: A: 7000, B: 2000, C: 1000
# M2: A: 1000, B: 7000, C: 2000
# M3: A: 2000, B: 1000, C: 7000
# Fractions: [[0.7 0.2 0.1]
#  [0.1 0.7 0.2]
#  [0.2 0.1 0.7]]
# 2025-01-03 13:00:16.762523: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-01-03 13:00:18.027307: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 46699 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:5e:00.0, compute capability: 8.6
# Epoch 1/200
# 2025-01-03 13:00:23.122979: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:630] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2025-01-03 13:00:23.177587: I tensorflow/compiler/xla/service/service.cc:173] XLA service 0x7efac401a620 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2025-01-03 13:00:23.177639: I tensorflow/compiler/xla/service/service.cc:181]   StreamExecutor device (0): NVIDIA RTX A6000, Compute Capability 8.6
# 2025-01-03 13:00:23.186273: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2025-01-03 13:00:23.484616: I tensorflow/compiler/jit/xla_compilation_cache.cc:477] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 30/30 [==============================] - 6s 30ms/step - loss: 1.0677 - accuracy: 0.4587 - val_loss: 0.9826 - val_accuracy: 0.5397
# Epoch 2/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.9571 - accuracy: 0.5662 - val_loss: 0.9493 - val_accuracy: 0.5900
# Epoch 3/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.9302 - accuracy: 0.5931 - val_loss: 0.9293 - val_accuracy: 0.6010
# Epoch 4/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.9188 - accuracy: 0.6008 - val_loss: 0.9224 - val_accuracy: 0.6033
# Epoch 5/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.9146 - accuracy: 0.6020 - val_loss: 0.9193 - val_accuracy: 0.6027
# Epoch 6/200
# 30/30 [==============================] - 0s 8ms/step - loss: 0.9129 - accuracy: 0.6029 - val_loss: 0.9181 - val_accuracy: 0.6083
# Epoch 7/200
# 30/30 [==============================] - 0s 12ms/step - loss: 0.9119 - accuracy: 0.6029 - val_loss: 0.9169 - val_accuracy: 0.6050
# Epoch 8/200
# 30/30 [==============================] - 0s 6ms/step - loss: 0.9116 - accuracy: 0.6028 - val_loss: 0.9162 - val_accuracy: 0.6040
# Epoch 9/200
# 30/30 [==============================] - 0s 5ms/step - loss: 0.9110 - accuracy: 0.6032 - val_loss: 0.9159 - val_accuracy: 0.6040
# Epoch 10/200
# 30/30 [==============================] - 0s 5ms/step - loss: 0.9112 - accuracy: 0.6027 - val_loss: 0.9152 - val_accuracy: 0.6047
# Epoch 11/200
# 30/30 [==============================] - 0s 6ms/step - loss: 0.9110 - accuracy: 0.6036 - val_loss: 0.9144 - val_accuracy: 0.6047
# Epoch 12/200
# 30/30 [==============================] - 0s 5ms/step - loss: 0.9105 - accuracy: 0.6037 - val_loss: 0.9156 - val_accuracy: 0.6030
# Epoch 13/200
# 30/30 [==============================] - 0s 6ms/step - loss: 0.9106 - accuracy: 0.6034 - val_loss: 0.9142 - val_accuracy: 0.6053
# Epoch 14/200
# 30/30 [==============================] - 0s 5ms/step - loss: 0.9103 - accuracy: 0.6021 - val_loss: 0.9140 - val_accuracy: 0.6043
# Epoch 15/200
# 30/30 [==============================] - 0s 5ms/step - loss: 0.9108 - accuracy: 0.6036 - val_loss: 0.9158 - val_accuracy: 0.6027
# Epoch 16/200
# 30/30 [==============================] - 0s 5ms/step - loss: 0.9102 - accuracy: 0.6031 - val_loss: 0.9145 - val_accuracy: 0.6063
# Epoch 17/200
# 30/30 [==============================] - 0s 8ms/step - loss: 0.9098 - accuracy: 0.6027 - val_loss: 0.9148 - val_accuracy: 0.6020
# Epoch 18/200
# 30/30 [==============================] - 0s 6ms/step - loss: 0.9101 - accuracy: 0.6044 - val_loss: 0.9145 - val_accuracy: 0.6040
# Epoch 19/200
# 30/30 [==============================] - 0s 6ms/step - loss: 0.9103 - accuracy: 0.6047 - val_loss: 0.9147 - val_accuracy: 0.6047
# Epoch 20/200
# 30/30 [==============================] - 0s 5ms/step - loss: 0.9098 - accuracy: 0.6030 - val_loss: 0.9140 - val_accuracy: 0.6037
# Epoch 21/200
# 30/30 [==============================] - 0s 5ms/step - loss: 0.9100 - accuracy: 0.6030 - val_loss: 0.9133 - val_accuracy: 0.6040
# Epoch 22/200
# 30/30 [==============================] - 0s 6ms/step - loss: 0.9093 - accuracy: 0.6035 - val_loss: 0.9135 - val_accuracy: 0.6050
# Epoch 23/200
# 30/30 [==============================] - 0s 6ms/step - loss: 0.9092 - accuracy: 0.6039 - val_loss: 0.9120 - val_accuracy: 0.6030
# Epoch 24/200
# 30/30 [==============================] - 0s 6ms/step - loss: 0.9093 - accuracy: 0.6024 - val_loss: 0.9135 - val_accuracy: 0.6017
# Epoch 25/200
# 30/30 [==============================] - 0s 6ms/step - loss: 0.9093 - accuracy: 0.6034 - val_loss: 0.9127 - val_accuracy: 0.6040
# Epoch 26/200
# 30/30 [==============================] - 0s 6ms/step - loss: 0.9094 - accuracy: 0.6039 - val_loss: 0.9129 - val_accuracy: 0.6043
# Epoch 27/200
# 30/30 [==============================] - 0s 6ms/step - loss: 0.9092 - accuracy: 0.6040 - val_loss: 0.9129 - val_accuracy: 0.6043
# Epoch 28/200
# 30/30 [==============================] - 0s 5ms/step - loss: 0.9089 - accuracy: 0.6034 - val_loss: 0.9136 - val_accuracy: 0.6017
# Epoch 29/200
# 30/30 [==============================] - 0s 6ms/step - loss: 0.9093 - accuracy: 0.6040 - val_loss: 0.9132 - val_accuracy: 0.6057
# Epoch 30/200
# 30/30 [==============================] - 0s 5ms/step - loss: 0.9090 - accuracy: 0.6039 - val_loss: 0.9126 - val_accuracy: 0.6077
# Epoch 31/200
# 30/30 [==============================] - 0s 6ms/step - loss: 0.9093 - accuracy: 0.6049 - val_loss: 0.9128 - val_accuracy: 0.6050
# Epoch 32/200
# 30/30 [==============================] - 0s 6ms/step - loss: 0.9099 - accuracy: 0.6045 - val_loss: 0.9136 - val_accuracy: 0.6063
# Epoch 33/200
# 30/30 [==============================] - 0s 6ms/step - loss: 0.9102 - accuracy: 0.6026 - val_loss: 0.9140 - val_accuracy: 0.6020
# Epoch 33: early stopping
# 30/30 [==============================] - 0s 2ms/step
# ACC: 0.604, ACCs: [0.5794, 0.5881, 0.6447]
# /home/r10222035/.conda/envs/tf2/lib/python3.8/site-packages/ternary/plotting.py:148: UserWarning: No data for colormapping provided via 'c'. Parameters 'vmin', 'vmax' will be ignored
#   ax.scatter(xs, ys, vmin=vmin, vmax=vmax, **kwargs)
# 30/30 [==============================] - 0s 3ms/step - loss: 0.9087 - accuracy: 0.6041
# Training Loss = 0.909, Training Accuracy = 0.604
# 3/3 [==============================] - 0s 2ms/step
# ACC: 0.829, ACCs: [0.785, 0.826, 0.877]
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6249 - accuracy: 0.8293
# Testing Loss = 0.625, Testing Accuracy = 0.829
# 30/30 [==============================] - 0s 3ms/step
# 3/3 [==============================] - 0s 2ms/step

# %%
save_path = f'./figures/multi-class_testing_data_predict-{case_name}-maxarg.pdf'
save_path = None
plot_predict_results(y_test, y_test_predict, y_test_predict.argmax(axis=1), title='Max argument', save_path=save_path)
plot_predict_results(y_true, y_predict, y_predict.argmax(axis=1), title='Max argument', save_path=save_path)

# %% [markdown]
# # Train another neural network on the dataset labeled by clustering method

# %% [markdown]
# ## K-means

# %%
kmeans = KMeans(n_clusters=3, random_state=45)
kmeans.fit(y_test_predict)
labels = kmeans.labels_
plot_predict_results(y_test, y_test_predict, labels, title='K-means Clustering')

kmeans = KMeans(n_clusters=3, random_state=45)
kmeans.fit(y_predict)
labels = kmeans.labels_
plot_predict_results(y_true, y_predict, labels, title='K-means Clustering')

# %%
model_kmeans = training_nn(X_train, np.eye(3)[labels], X_val, y_val, y_true, X_test, y_test)
y_predict_kmeans = model_kmeans.predict(X_train, batch_size=1024)
y_test_predict_kmeans = model_kmeans.predict(X_test, batch_size=1024)
# Out:
# M1: A: 1280, B: 4, C: 8664
# M2: A: 1063, B: 8366, C: 4
# M3: A: 7657, B: 1630, C: 1332
# Fractions: [[1.28669079e-01 4.02090873e-04 8.70928830e-01]
#  [1.12689494e-01 8.86886462e-01 4.24043252e-04]
#  [7.21066014e-01 1.53498446e-01 1.25435540e-01]]
# Epoch 1/200
# 30/30 [==============================] - 2s 13ms/step - loss: 0.7913 - accuracy: 0.6613 - val_loss: 1.9259 - val_accuracy: 0.3617
# Epoch 2/200
# 30/30 [==============================] - 0s 6ms/step - loss: 0.3442 - accuracy: 0.8914 - val_loss: 3.0968 - val_accuracy: 0.3480
# Epoch 3/200
# 30/30 [==============================] - 0s 6ms/step - loss: 0.1854 - accuracy: 0.9628 - val_loss: 4.6577 - val_accuracy: 0.3423
# Epoch 4/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0987 - accuracy: 0.9818 - val_loss: 6.3591 - val_accuracy: 0.3437
# Epoch 5/200
# 30/30 [==============================] - 0s 6ms/step - loss: 0.0609 - accuracy: 0.9886 - val_loss: 7.7820 - val_accuracy: 0.3367
# Epoch 6/200
# 30/30 [==============================] - 0s 6ms/step - loss: 0.0462 - accuracy: 0.9895 - val_loss: 9.0280 - val_accuracy: 0.3377
# Epoch 7/200
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0385 - accuracy: 0.9913 - val_loss: 9.9805 - val_accuracy: 0.3377
# Epoch 8/200
# 30/30 [==============================] - 0s 6ms/step - loss: 0.0346 - accuracy: 0.9913 - val_loss: 10.6207 - val_accuracy: 0.3380
# Epoch 9/200
# 30/30 [==============================] - 0s 6ms/step - loss: 0.0327 - accuracy: 0.9907 - val_loss: 11.1466 - val_accuracy: 0.3370
# Epoch 10/200
# 30/30 [==============================] - 0s 6ms/step - loss: 0.0291 - accuracy: 0.9919 - val_loss: 11.7601 - val_accuracy: 0.3387
# Epoch 11/200
# 30/30 [==============================] - 0s 6ms/step - loss: 0.0281 - accuracy: 0.9912 - val_loss: 12.4264 - val_accuracy: 0.3380
# Epoch 11: early stopping
# 30/30 [==============================] - 0s 2ms/step
# ACC: 0.992, ACCs: [0.9944712505026135, 0.996713664793809, 0.9852151803371315]
# /home/r10222035/.conda/envs/tf2/lib/python3.8/site-packages/ternary/plotting.py:148: UserWarning: No data for colormapping provided via 'c'. Parameters 'vmin', 'vmax' will be ignored
#   ax.scatter(xs, ys, vmin=vmin, vmax=vmax, **kwargs)
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0263 - accuracy: 0.9919
# Training Loss = 0.0263, Training Accuracy = 0.992
# 3/3 [==============================] - 0s 3ms/step
# ACC: 0.827, ACCs: [0.789, 0.833, 0.86]
# 3/3 [==============================] - 0s 4ms/step - loss: 12.8204 - accuracy: 0.3640
# Testing Loss = 12.8, Testing Accuracy = 0.364
# 30/30 [==============================] - 0s 3ms/step
# 3/3 [==============================] - 0s 2ms/step

# %%
plot_predict_results(y_test, y_test_predict_kmeans, y_test_predict_kmeans.argmax(axis=1), title='NN2 Max argument')
plot_predict_results(y_true, y_predict_kmeans, y_predict_kmeans.argmax(axis=1), title='NN2 Max argument')

# %% [markdown]
# ## Spectral clustering

# %%
spectral = SpectralClustering(n_clusters=3, affinity='nearest_neighbors', random_state=45)
labels = spectral.fit_predict(y_test_predict)
plot_predict_results(y_test, y_test_predict, labels, title='Spectral Clustering')

spectral = SpectralClustering(n_clusters=3, affinity='nearest_neighbors', random_state=45, n_jobs=16)
labels = spectral.fit_predict(y_predict)
plot_predict_results(y_true, y_predict, labels, title='Spectral Clustering')

# %%
model_spectral = training_nn(X_train, np.eye(3)[labels], X_val, y_val, y_true, X_test, y_test)
y_predict_spectral = model_spectral.predict(X_train, batch_size=1024)
y_test_predict_spectral = model_spectral.predict(X_test, batch_size=1024)
# Out:
# M1: A: 7907, B: 2131, C: 1243
# M2: A: 1360, B: 5, C: 8755
# M3: A: 733, B: 7864, C: 2
# Fractions: [[7.00913040e-01 1.88901693e-01 1.10185267e-01]
#  [1.34387352e-01 4.94071146e-04 8.65118577e-01]
#  [8.52424701e-02 9.14524945e-01 2.32585184e-04]]
# Epoch 1/200
# 30/30 [==============================] - 1s 12ms/step - loss: 0.9493 - accuracy: 0.4733 - val_loss: 2.2375 - val_accuracy: 0.2730
# Epoch 2/200
# 30/30 [==============================] - 0s 8ms/step - loss: 0.5522 - accuracy: 0.7380 - val_loss: 4.5762 - val_accuracy: 0.2740
# Epoch 3/200
# 30/30 [==============================] - 0s 8ms/step - loss: 0.2391 - accuracy: 0.9182 - val_loss: 8.1146 - val_accuracy: 0.2997
# Epoch 4/200
# 30/30 [==============================] - 0s 6ms/step - loss: 0.1043 - accuracy: 0.9649 - val_loss: 10.0606 - val_accuracy: 0.3033
# Epoch 5/200
# 30/30 [==============================] - 0s 6ms/step - loss: 0.0641 - accuracy: 0.9814 - val_loss: 11.1656 - val_accuracy: 0.3073
# Epoch 6/200
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0514 - accuracy: 0.9854 - val_loss: 12.2192 - val_accuracy: 0.3067
# Epoch 7/200
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0442 - accuracy: 0.9874 - val_loss: 12.9813 - val_accuracy: 0.3090
# Epoch 8/200
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0398 - accuracy: 0.9890 - val_loss: 13.9165 - val_accuracy: 0.3077
# Epoch 9/200
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0372 - accuracy: 0.9891 - val_loss: 14.4995 - val_accuracy: 0.3093
# Epoch 10/200
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0338 - accuracy: 0.9901 - val_loss: 15.2717 - val_accuracy: 0.3087
# Epoch 11/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0320 - accuracy: 0.9902 - val_loss: 15.9419 - val_accuracy: 0.3077
# Epoch 11: early stopping
# 30/30 [==============================] - 0s 1ms/step
# ACC: 0.988, ACCs: [0.9769523978370712, 0.9900197628458498, 0.9997674148156762]
# /home/r10222035/.conda/envs/tf2/lib/python3.8/site-packages/ternary/plotting.py:148: UserWarning: No data for colormapping provided via 'c'. Parameters 'vmin', 'vmax' will be ignored
#   ax.scatter(xs, ys, vmin=vmin, vmax=vmax, **kwargs)
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0323 - accuracy: 0.9879
# Training Loss = 0.0323, Training Accuracy = 0.988
# 3/3 [==============================] - 0s 2ms/step
# ACC: 0.823, ACCs: [0.807, 0.797, 0.866]
# 3/3 [==============================] - 0s 8ms/step - loss: 19.0149 - accuracy: 0.2690
# Testing Loss = 19.0, Testing Accuracy = 0.269
# 30/30 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 4ms/step

# %%
plot_predict_results(y_test, y_test_predict_spectral, y_test_predict_spectral.argmax(axis=1), title='NN2 Max argument')
plot_predict_results(y_true, y_predict_spectral, y_predict_spectral.argmax(axis=1), title='NN2 Max argument')
